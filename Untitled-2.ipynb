# %% [markdown]
# # Prepare all the heavy objects

# %%
from importlib import reload
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import math
import seaborn as sns
from scipy import stats
import subprocess

import utilsV3
import optimizationV3
import utils
import datetime


reload(utils)
reload(utilsV3)
reload(optimizationV3)


ORIGINAL_DIM = 640

def create_objf(is_extended=True):
    D = utilsV3.CriteriaD(is_extended)
    F = utilsV3.CriteriaF(D)
    return D, F

def create_dim_red(reduced_dim):
    return utils.SegmentsDimReduction(ORIGINAL_DIM, reduced_dim)

def create_objf_reduced(f, reduced_dim):
    return utilsV3.ReducedDimObjFunSRON(reduced_dim, f)

def create_objf_profiled(f, config):
    return utilsV3.ProfiledF(f, config)

def get_datetime_str():
    return datetime.datetime.now().strftime('%d-%m-%Y_%Hh%Mm%Ss')

def create_distance(f, d0_method, d1_method):
    dist_matrix = utils.create_dist_matrix(f, d0_method)
    dist = utils.create_distance(f, dist_matrix, d1_method)
    return dist_matrix, dist

def create_dist_matrix_sorted(dist_matrix):
    return utilsV3.sort_dist_matrix(dist_matrix)

def crop_pdf(pdfname):
    subprocess.run(['pdfcrop', pdfname])

# %%
dim_red_16 = create_dim_red(16)
D, F = create_objf(True)
D_old, F_old = create_objf(False)
Fr = create_objf_reduced(F, 16)
Fr_old = create_objf_reduced(F_old, 16)
dist_matrix_2, dist_2_kirill = create_distance(F, '2', 'kirill')
dist_matrix_2_sorted = create_dist_matrix_sorted(dist_matrix_2)
LIBRARY_SIZE = F.instrument.filterlibrarysize
# Out:
# Loading radiance model...
# Loading filter library...
# Loading radiance model...
# Loading filter library...

# %%
plt.rc('text', usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.size'] = 15

# %%
dist_matrix_3, dist_3_kirill = create_distance(F, '3', 'kirill')
dist_matrix_3_sorted = create_dist_matrix_sorted(dist_matrix_3)

# %%
x0 = D.instrument.filterguess()
x0_ind = optimizationV3.Individual(F, x0, None)
x0_ind.add_samples(10000)
print(x0_ind.obj_value())
# Out:
# 0.001260907604867861

# %%
with open('sron-baseline-extended-samples.csv', 'w') as file:
    print(*x0_ind.objf_x_samples, file=file)

# %%
x0_old = D_old.instrument.filterguess()
x0_old_ind = optimizationV3.Individual(F_old, x0_old, None)
x0_old_ind.add_samples(10000)
print(x0_old_ind.obj_value())
# Out:
# 0.00024995481764376626

# %%
dim_red = create_dim_red(16)
# x1 = [int(i) for i in '3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 741 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 3258 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2982 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2071 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2977 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 2938 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 3852 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 4209 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3982 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 3867 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103'.split(' ')]
# x1 = [int(i) for i in '2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 2431, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 2968, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 2169, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 491, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 2215, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 3918, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 3442, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 2983, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 4106, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531'.split(', ')]
# x1 = [int(i) for i in '3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 3490, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 1206, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 2133, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3845, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 3408, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 356, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 801, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 2097, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 815, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843, 843'.split(', ')]
# x1 = [int(i) for i in '1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 1015, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 2605, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 3451, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 2585, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1263, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 1033, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3882, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 3120, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 2509, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3982, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 3066, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 2488, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 1840, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 790, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476, 2476'.split(', ')]
# x1 = [int(i) for i in '924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 924, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 3020, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 741, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 803, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 2906, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 746, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 1360, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 826, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 988, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025, 3025'.split(', ')]
# x1 = [int(i) for i in '60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355'.split(', ')]
# x1 = dim_red.to_original([int(i) for i in '2676 3000 1052 2969 370 2966 3024 1770 1690 22 2642 2991 60 1725 60 247'.split(' ')])
# x1 = dim_red.to_original([int(i) for i in '75 60 797 103 144 729 2521 1502 2312 2892 1653 1531 2469 1970 2456 1601'.split(' ')])
x1 = [int(i) for i in '3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 3027 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 813 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 2487 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 103 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 2865 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 3048 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 89 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 60 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 2169 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 797 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 729 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2266 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2966 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2237 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996 2996'.split(' ')]
print(len(set(x1)))
x1_ind = optimizationV3.Individual(F, x1)
x1_ind.add_samples(10000)
print(x1_ind.obj_value())
# Out:
# 16
# 0.0001833647177540405

# %%
print('mean x0', np.mean(x0_ind.objf_x_samples))
print('mean x1', np.mean(x1_ind.objf_x_samples))

print('var x0', np.var(x0_ind.objf_x_samples))
print('var x1', np.var(x1_ind.objf_x_samples))

print('F(x0)', np.mean(x0_ind.objf_x_samples)**2 + np.var(x0_ind.objf_x_samples))
print('F(x1)', np.mean(x1_ind.objf_x_samples)**2 + np.var(x1_ind.objf_x_samples))

len(set(x1_ind.x))
# Out:
# mean x0 -0.0007323484452433475
# mean x1 -0.0001238599243790327
# var x0 0.0012603712706226106
# var x1 0.00018334937647317332
# F(x0) 0.001260907604867861
# F(x1) 0.00018336471775404052
# 16

# %%
def plot_dist(D_samples, N, filename, mode=None):
    fig, ax = plt.subplots()
    cdf_normal = lambda x, m, s: 1/2*(1+math.erf((x-m)/(s*math.sqrt(2))))
    m = np.mean(D_samples)
    s = np.std(D_samples)
    dx = (max(D_samples) - min(D_samples)) / N
    x_ = np.arange(min(D_samples), max(D_samples), dx)
    while len(x_) > N:
        x_ = x_[:-1]
    y = [(cdf_normal(x+dx, m, s) - cdf_normal(x, m, s)) for x in x_]
    # plt.hist(D_samples, bins=N, color='gray')
    ax = sns.histplot(D_samples, kde=False, stat='probability', color='gray', label='Samples', bins=N)
    plt.plot(x_+dx/2, y, linestyle='--', color='purple', label='Max Likelihood Gaussian of SRON baseline')
    plt.xlim(-0.16, 0.16)
    plt.ylim(0, 0.06)
    plt.xticks([-0.15, -0.1, -0.05, 0, 0.05, 0.1, 0.15])
    # plt.legend(loc='best', ncol=1)
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    plt.show()
    pdfname=f'{filename}.pdf'
    fig.savefig(pdfname)
    crop_pdf(pdfname)

# %%
plot_dist(x0_ind.objf_x_samples, 60, 'noise-sron-baseline')
plot_dist(x1_ind.objf_x_samples, 60, 'noise-best-found')
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `noise-sron-baseline-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `noise-best-found-crop.pdf'.

# %%
def find_maximal_likelihood_gaussian(D_samples, N):
    cdf_normal = lambda x, m, s: 1/2*(1+math.erf((x-m)/(s*math.sqrt(2))))
    m = np.mean(D_samples)
    s = np.std(D_samples)
    dx = (max(D_samples) - min(D_samples)) / N
    x_ = np.arange(min(D_samples), max(D_samples), dx)
    if len(x_) > N:
        x_ = x_[:N]
    y = [(cdf_normal(x+dx, m, s) - cdf_normal(x, m, s)) for x in x_]
    return x_+dx/2, y
    

def plot_dist_1(D_x0_samples, D_samples, N, filename, mode=None):
    fig, ax = plt.subplots()
    ax = sns.histplot(D_samples, kde=False, stat='probability', color='gray', label='Samples', bins=N)
    x, y = find_maximal_likelihood_gaussian(D_x0_samples, N)
    plt.plot(x, y, linestyle='--', color='purple', label=r'Max Likelihood Gaussian of SRON baseline $\boldsymbol{x}_{\text{base}}$')
    ax.fill_between(x, 0, y, facecolor='purple', alpha=0.20)

    x, y = find_maximal_likelihood_gaussian(D_samples, N)
    plt.plot(x, y, color='red', label=r'Max Likelihood Gaussian of Top Solution $\boldsymbol{x}^{(1)}$')
    plt.xlim(-0.16, 0.16)
    plt.ylim(0, 0.06)
    plt.xticks([-0.15, -0.1, -0.05, 0, 0.05, 0.1, 0.15])
    # plt.legend(loc='best', ncol=1)
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    # ax.set_axis_off()
    plt.show()
    pdfname=f'{filename}.pdf'
    fig.savefig(pdfname)
    crop_pdf(pdfname)


plot_dist_1(x0_ind.objf_x_samples, x1_ind.objf_x_samples, 60, 'noise-best-found')
# plot_dist_1(x0_ind.objf_x_samples, x1_ind.objf_x_samples, 60, 'noise-best-found-legend')
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `noise-best-found-crop.pdf'.

# %%
import myrandom as myrnd
import seaborn as sns
import tikzplotlib


reload(myrnd)

D = myrnd.RandomEngine.TruncatedExponentialDistribution().build(0.1, 1e-9)

def plot_dist_1(D_samples, D, N, filename):
    fig, ax = plt.subplots()
    m = np.mean(D_samples)
    s = np.std(D_samples)
    dx = (max(D_samples) - min(D_samples)) / N
    x_ = np.arange(min(D_samples), max(D_samples), dx)
    while len(x_) > N:
        x_ = x_[:-1]
    y = [(D.cdf(x+dx) - D.cdf(x)) for x in x_]
    # plt.hist(D_samples, bins=N, color='gray')
    ax = sns.histplot(D_samples, kde=False, stat='probability', color='gray', label='Samples', bins=N)
    ax.plot(x_+dx/2, y, color='red', label='Distribution')
    ax.axvline(x=D.mean,color='red',linestyle='dashed', label=f'Mean {D.mean:.1f}')
    plt.xticks(np.arange(0, 1, 0.1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    plt.legend()
    pdfname=f'{filename}.pdf'
    fig.savefig(pdfname)
    crop_pdf(pdfname)


D_samples = np.array([D.sample() for _ in range(10000)])
plot_dist_1(D_samples, D, 60, 'step-size-distr')
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `step-size-distr-crop.pdf'.

# %%
patches = []
name_to_color = {}

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'dynamics'
    processed_csv = ['processed/ea-simple.csv', 'processed/ea-simple-cross.csv', 
                     'processed/dd-ga.csv', 
                    'processed/dd-ga-1.csv',
                    #  'processed/dd-opll.csv', 
                     'processed/dd-ls.csv', 
                     'processed/mies.csv', 'processed/ngopt.csv', 
                     'processed/portfolio-ng.csv', 'processed/fastga-ng.csv', 
                     'processed/bo-ng.csv', 'processed/umda.csv'
                     ]
    # processed_csv = ['processed/bo-ng.csv']
    labels = [r'$(\mu + \lambda)$ EA', r'$(\mu/2 + \lambda)$ EA', 
              r'DD-$(\mu/2 + \lambda)$ EA $10^2$', 
              r'DD-$(\mu/2 + \lambda)$ EA $10^3$', 
            #   r'DD-$\left( 1 + \left(\lambda, \lambda \right) \right)$', 
              r'DD-$(1+1)$ EA $10^2$', 
              r'$(\mu/2, \lambda)$ MIES', r'NGOpt (Nevergrad)',
              r'Noisy Portfolio (Nevergrad)', r'Integer Fast GA (Nevergrad)',
              r'Baysian Optimization', r'$(\mu + \lambda)$ UMDA'
              ]
    # labels = [r'BO (Nevergrad)']
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[4] = mpl.cm.jet(0.7)
    sron_guess = x0_ind.objf_x_samples**2

    global patches
    if mode != 'legend':
        patches.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    CUT = 0
    bo_f_evals = 0
    bo_pos_in_list = 0
    for i, f in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]            
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][CUT:]
        y = df['mean'][CUT:]
        min_ = df['min'][CUT:]
        err = df['std'][CUT:]/np.sqrt(df['cnt'][CUT:])
        if alg_name == 'bo-ng':
            bo_f_evals = len(x)
            bo_pos_in_list = i
        if mode != 'legend':
            if mode == 'mean':
                values = y
            elif mode == 'min':
                values = min_
            patch, = plt.plot(x, values, c=colors[i], label=labels[i], lw=1.5)
            patches.append(patch)
            print(patch.get_lw())
        # else:
        #     # patch = mpl.patches.Patch(color=colors[i], label=labels[i], ls='-', lw=2)
        #     patches.append(patch)
        # ax.fill_between(x, y - err, y + err, facecolor=colors[i], alpha=0.20)
        # argmin = np.argmin(y)
        # print(y[argmin])
        # print(err[argmin])

        x_ = df.loc[:, 'argmin_x0':'argmin_x639']
        argmin1 = np.argmin(min_)
        print(alg_name)
        print(min_[argmin1])
        print(x_.iloc[argmin1].to_list())

    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    # plt.plot(x, [sron_guess_mean]*len(x), c='black', label='SRON baseline', linestyle='--')
    if mode != 'legend':
        patch = plt.axhline(y=sron_guess_mean,color='black', linestyle='dashed', label='SRON baseline')
        patches.append(patch)
        patch = plt.axvline(x=bo_f_evals, color=colors[bo_pos_in_list], linestyle='dashed', label='BO max budget')
        patches.append(patch)
    # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
    plt.ylabel(f'{mode.capitalize()} $F$ value', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-4), 10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    # fig.tight_layout()
    if mode != 'legend':
        # plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=3)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('mean')
build_plot('min')
build_plot('legend')
# print(patches)
# Out:
# 1.5
# ea-simple
# 0.0002132058454337
# ...

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'dynamics'
    processed_csv = ['processed/umda.csv',
                     'processed/umda-new-16.csv', 
                     'processed/umda-new-32.csv', 
                     'processed/umda-new-64.csv',
                     ]
    # processed_csv = ['processed/bo-ng.csv']
    labels = [r'UMDA, $\mu = 5, \lambda = 50, n = 16$',
              r'UMDA, $\mu = 10, \lambda = 100, n = 16$',
              r'UMDA, $\mu = 10, \lambda = 100, n = 32$',
              r'UMDA, $\mu = 10, \lambda = 100, n = 64$',
              ]
    # labels = [r'BO (Nevergrad)']
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[4] = mpl.cm.jet(0.7)
    sron_guess = x0_ind.objf_x_samples**2

    global patches
    if mode != 'legend':
        patches.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    CUT = 0
    bo_f_evals = 0
    bo_pos_in_list = 0
    for i, f in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]            
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][CUT:]
        y = df['mean'][CUT:]
        min_ = df['min'][CUT:]
        err = df['std'][CUT:]/np.sqrt(df['cnt'][CUT:])
        if alg_name == 'bo-ng':
            bo_f_evals = len(x)
            bo_pos_in_list = i
        if mode != 'legend':
            if mode == 'mean':
                values = y
            elif mode == 'min':
                values = min_
            patch, = plt.plot(x, values, c=colors[i], label=labels[i], lw=1.5)
            patches.append(patch)
            print(patch.get_lw())
        # else:
        #     # patch = mpl.patches.Patch(color=colors[i], label=labels[i], ls='-', lw=2)
        #     patches.append(patch)
        # ax.fill_between(x, y - err, y + err, facecolor=colors[i], alpha=0.20)
        # argmin = np.argmin(y)
        # print(y[argmin])
        # print(err[argmin])

        x_ = df.loc[:, 'argmin_x0':'argmin_x639']
        argmin1 = np.argmin(min_)
        print(alg_name)
        print(min_[argmin1])
        print(x_.iloc[argmin1].to_list())

    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    # plt.plot(x, [sron_guess_mean]*len(x), c='black', label='SRON baseline', linestyle='--')
    if mode != 'legend':
        patch = plt.axhline(y=sron_guess_mean,color='black', linestyle='dashed', label='SRON baseline')
        patches.append(patch)
        # patch = plt.axvline(x=bo_f_evals, color=colors[bo_pos_in_list], linestyle='dashed', label='BO max budget')
        # patches.append(patch)
    # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
    plt.ylabel(f'{mode.capitalize()} $F$ value', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-4), 10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    # fig.tight_layout()
    if mode != 'legend':
        # plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=3)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('mean')
build_plot('min')
build_plot('legend')
# print(patches)
# Out:
# 1.5
# umda
# 0.000153670143605
# ...

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'dynamics'
    processed_csv = ['processed/ea-simple.csv', 
                     'processed/ea-simple-cross.csv', 
                     'processed/dd-ga.csv', 
                     'processed/dd-ga-1.csv',
                     'processed/umda.csv',
                     'processed/umda1-mu-5.csv', 
                     'processed/umda1-mu-10.csv', 
                     ]
    # processed_csv = ['processed/bo-ng.csv']
    labels = [r'$(\mu + \lambda)$ EA', 
              r'$(\mu/2 + \lambda)$ EA', 
              r'DD-$(\mu/2 + \lambda)$ EA $10^2$', 
              r'DD-$(\mu/2 + \lambda)$ EA $10^3$',
              r'UMDA, $\mu = 5, \lambda = 50, n = 16$',
              r'UMDA1, $\mu = 5, \lambda = 50, n = 16$',
              r'UMDA1, $\mu = 10, \lambda = 100, n = 32$',
              ]
    # labels = [r'BO (Nevergrad)']
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[4] = mpl.cm.jet(0.7)
    sron_guess = x0_ind.objf_x_samples**2

    global patches
    if mode != 'legend':
        patches.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    CUT = 0
    bo_f_evals = 0
    bo_pos_in_list = 0
    for i, f in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]            
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][CUT:]
        y = df['mean'][CUT:]
        min_ = df['min'][CUT:]
        err = df['std'][CUT:]/np.sqrt(df['cnt'][CUT:])
        if alg_name == 'bo-ng':
            bo_f_evals = len(x)
            bo_pos_in_list = i
        if mode != 'legend':
            if mode == 'mean':
                values = y
            elif mode == 'min':
                values = min_
            patch, = plt.plot(x, values, c=colors[i], label=labels[i], lw=1.5)
            patches.append(patch)
            print(patch.get_lw())
        # else:
        #     # patch = mpl.patches.Patch(color=colors[i], label=labels[i], ls='-', lw=2)
        #     patches.append(patch)
        # ax.fill_between(x, y - err, y + err, facecolor=colors[i], alpha=0.20)
        # argmin = np.argmin(y)
        # print(y[argmin])
        # print(err[argmin])

        x_ = df.loc[:, 'argmin_x0':'argmin_x639']
        argmin1 = np.argmin(min_)
        print(alg_name)
        print(min_[argmin1])
        print(x_.iloc[argmin1].to_list())

    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    # plt.plot(x, [sron_guess_mean]*len(x), c='black', label='SRON baseline', linestyle='--')
    if mode != 'legend':
        patch = plt.axhline(y=sron_guess_mean,color='black', linestyle='dashed', label='SRON baseline')
        patches.append(patch)
        # patch = plt.axvline(x=bo_f_evals, color=colors[bo_pos_in_list], linestyle='dashed', label='BO max budget')
        # patches.append(patch)
    # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
    plt.ylabel(f'{mode.capitalize()} $F$ value', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-5), 10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    # fig.tight_layout()
    if mode != 'legend':
        # plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=3)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('mean')
build_plot('min')
build_plot('legend')
# print(patches)
# Out:
# 1.5
# ea-simple
# 0.0002132058454337
# ...

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'dynamics'
    processed_csv = [
        # ('processed/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
        # ('processed/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA'), 
        # ('processed/dd-ga.csv', r'DD-$(\mu/2 + \lambda)$ EA $10^2$'), 
        # ('processed/dd-ga-1.csv', r'DD-$(\mu/2 + \lambda)$ EA $10^3$'),
        ('processed/umda.csv', r'UMDA, $\mu = 5, \lambda = 50, n = 16$'),
        # ('processed/umda1-mu-5.csv', r'UMDA1, $\mu = 5, \lambda = 50, n = 16$'), 
        # ('processed/umda2_d0-2.csv', r'UMDA2, $\mu=5, \lambda = 50, d_0 = 2$'),
        # ('processed/umda2_d0-3.csv', r'UMDA2, $\mu=5, \lambda = 50, d_0 = 3$'),
        ('processed/umda2-dist_d0-2.csv', r'UMDA2-dist, $\mu=5, \lambda = 50, d_0 = 2$'),
        # ('processed/umda2-dist_d0-3.csv', r'UMDA2-dist, $\mu=5, \lambda = 50, d_0 = 3$'),
        ]
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[4] = mpl.cm.jet(0.7)
    sron_guess = x0_ind.objf_x_samples**2

    global patches
    if mode != 'legend':
        patches.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    CUT = 0
    bo_f_evals = 0
    bo_pos_in_list = 0
    for i, (f, label) in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]            
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][CUT:]
        y = df['mean'][CUT:]
        min_ = df['mean_best_so_far'][CUT:]
        err = df['std'][CUT:]/np.sqrt(df['cnt'][CUT:])
        if alg_name == 'bo-ng':
            bo_f_evals = len(x)
            bo_pos_in_list = i
        if mode != 'legend':
            if mode == 'mean':
                values = y
            elif mode == 'best-so-far':
                values = min_
                err = df['std_best_so_far'][CUT:]
            patch, = plt.plot(x, values, c=colors[i], label=label, lw=1.5)
            ax.fill_between(x, values - err, values + err, facecolor=colors[i], alpha=0.20)
            patches.append(patch)
            print(patch.get_lw())
        # else:
        #     # patch = mpl.patches.Patch(color=colors[i], label=labels[i], ls='-', lw=2)
        #     patches.append(patch)
        # ax.fill_between(x, y - err, y + err, facecolor=colors[i], alpha=0.20)
        # argmin = np.argmin(y)
        # print(y[argmin])
        # print(err[argmin])

        x_ = df.loc[:, 'argmin_x0':'argmin_x639']
        argmin1 = np.argmin(min_)
        print(alg_name)
        print(min_[argmin1])
        print(x_.iloc[argmin1].to_list())

    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    # plt.plot(x, [sron_guess_mean]*len(x), c='black', label='SRON baseline', linestyle='--')
    if mode != 'legend':
        patch = plt.axhline(y=sron_guess_mean,color='black', linestyle='dashed', label='SRON baseline')
        patches.append(patch)
        # patch = plt.axvline(x=bo_f_evals, color=colors[bo_pos_in_list], linestyle='dashed', label='BO max budget')
        # patches.append(patch)
    # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
    plt.ylabel(f'{mode.capitalize()} $F$ value', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-4), 10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    # fig.tight_layout()
    if mode != 'legend':
        # plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=3)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('mean')
build_plot('best-so-far')
build_plot('legend')
# print(patches)
# Out:
# 1.5
# umda
# 0.0003118534829845
# ...

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'dynamics'
    initial_algs_csv = [
        ('processedAfter-22-05-2024/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
        ('processedAfter-22-05-2024/ngopt.csv', r'NGOpt'), 
        ('processedAfter-22-05-2024/mies.csv', r'$(\mu/2, \lambda)$ MIES'), 
        ('processedAfter-22-05-2024/fastga-ng.csv', r'Integer Fast GA'), 
        ('processedAfter-22-05-2024/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA'), 
        ('processedAfter-22-05-2024/portfolio.csv', r'Noisy Portfolio'), 
        ('processedAfter-22-05-2024/umda.csv', r'UMDA'),        
        ('processedAfter-22-05-2024/bo-sk.csv', r'BO'),
    ]
    extended_algs_csv = [
        ('processedAfter-22-05-2024/dd-ga.csv', r'DD-$(\mu/2 + \lambda)$ EA'),
        ('processedAfter-22-05-2024/umda1.csv', r'UMDA1, $\mu = 5, \lambda = 50$'),
        ('processedAfter-22-05-2024/umda2.csv', r'UMDA2, $\mu = 5, \lambda = 50$'),
        ('processedAfter-22-05-2024/umda2-dist_d0-2.csv', r'UMDA2-dist, $\mu = 5, \lambda = 50, d_0 = 2$'),
        ('processedAfter-22-05-2024/umda2-dist_d0-3.csv', r'UMDA2-dist, $\mu = 5, \lambda = 50, d_0 = 3$'),
    ]
    processed_csv = initial_algs_csv
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[2] = mpl.cm.jet(2.7/7)
    colors[5] = mpl.cm.jet(0.8)
    sron_guess = x0_ind.objf_x_samples**2

    global patches
    if mode != 'legend':
        patches.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    cut_tail = 2100
    cut_tail_bo = 1000
    bo_pos_in_list = 0
    if mode == 'best-so-far':
        LW = 2.5
    else:
        LW = 1.5
    for i, (f, label) in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]  
        if alg_name == 'bo-sk':
            cut_tail = cut_tail_bo
            bo_pos_in_list = i
        else:
            cut_tail == 2100          
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][:cut_tail]
        y = df['mean'][:cut_tail]
        min_ = df['mean_best_so_far'][:cut_tail]
        err = df['std'][:cut_tail]/np.sqrt(df['cnt'][:cut_tail])
        if mode != 'legend':
            if mode == 'mean':
                values = y
            elif mode == 'best-so-far':
                values = min_
                err = df['std_best_so_far'][:cut_tail]
            patch, = plt.plot(x, values, c=colors[i], label=label, lw=LW)
            ax.fill_between(x, values - err, values + err, facecolor=colors[i], alpha=0.20)
            patches.append(patch)
            # print(patch.get_lw())

        x_ = df.loc[:, 'argmin_x0':'argmin_x639']
        argmin1 = np.argmin(min_)
        print(alg_name)
        print(min_[argmin1])
        print(x_.iloc[argmin1].to_list())

    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    if mode != 'legend':
        patch = plt.axhline(y=sron_guess_mean,color='black', linestyle='dashed', label='SRON baseline')
        patches.append(patch)
        # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
        patch = plt.axvline(x=cut_tail_bo, color=colors[bo_pos_in_list], linestyle='dashed', label='BO max budget')
        patches.append(patch)
    if mode == 'best-so-far':
        ax.yaxis.set_label_position("right")
        ax.yaxis.tick_right()
        name = 'Averaged best-so-far'
        plt.ylabel(f'{name.capitalize()} $F$ value', labelpad=10, fontsize=12, rotation=270)
    else:
        name = mode
        plt.ylabel(f'{name.capitalize()} $F$ value', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-4), 10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    if mode != 'legend':
        # plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=1)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('mean')
build_plot('best-so-far')
build_plot('legend')
# print(patches)
# Out:
# ea-simple
# 0.0002925077626161
# ...

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'dynamics-leading-extensions'
    initial_algs_csv = [
        ('processedAfter-22-05-2024/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
        ('processedAfter-22-05-2024/ngopt.csv', r'NGOpt'), 
        ('processedAfter-22-05-2024/mies.csv', r'$(\mu/2, \lambda)$ MIES'), 
        ('processedAfter-22-05-2024/fastga-ng.csv', r'Integer Fast GA'), 
        ('processedAfter-22-05-2024/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA'), 
        ('processedAfter-22-05-2024/portfolio.csv', r'Noisy Portfolio'), 
        ('processedAfter-22-05-2024/umda.csv', r'UMDA'),        
        ('processedAfter-22-05-2024/bo-sk.csv', r'BO'),
    ]
    leading_algs_csv = [
        ('processedAfter-22-05-2024/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
        ('processedAfter-22-05-2024/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA'), 
        ('processedAfter-22-05-2024/umda.csv', r'UMDA'),
    ]
    extended_algs_csv = [
        ('processedAfter-22-05-2024/dd-ga.csv', r'DD-$(\mu/2 + \lambda)$ EA'),
        ('processedAfter-22-05-2024/umda1.csv', r'UMDA-U'),
        ('processedAfter-22-05-2024/umda2.csv', r'UMDA-U-PLS'),
        ('processedAfter-22-05-2024/umda2-dist_d0-2.csv', r'UMDA-U-PLS-Dist, $d_a$'),
        ('processedAfter-22-05-2024/umda2-dist_d0-3.csv', r'UMDA-U-PLS-Dist, $d_b$'),
    ]
    processed_csv = leading_algs_csv + extended_algs_csv
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[2] = mpl.cm.jet(2.7/7)
    colors[5] = mpl.cm.jet(0.8)
    sron_guess = x0_ind.objf_x_samples**2

    global patches, name_to_color
    if mode != 'legend':
        patches.clear()
        name_to_color.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    cut_tail = 2100
    cut_tail_bo = 1000
    bo_pos_in_list = 0
    if mode == 'best-so-far':
        LW = 2.5
    else:
        LW = 1.5
    for i, (f, label) in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]  
        if alg_name == 'bo-sk':
            cut_tail = cut_tail_bo
            bo_pos_in_list = i
        else:
            cut_tail == 2100          
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][:cut_tail]
        y = df['mean'][:cut_tail]
        min_ = df['mean_best_so_far'][:cut_tail]
        err = df['std'][:cut_tail]/np.sqrt(df['cnt'][:cut_tail])
        name_to_color[label] = colors[i]
        if mode != 'legend':
            if mode == 'mean':
                values = y
            elif mode == 'best-so-far':
                values = min_
                err = df['std_best_so_far'][:cut_tail]
            patch, = plt.plot(x, values, c=colors[i], label=label, lw=LW)
            ax.fill_between(x, values - err, values + err, facecolor=colors[i], alpha=0.20)
            patches.append(patch)
            # print(patch.get_lw())

        # x_ = df.loc[:, 'argmin_x0':'argmin_x639']
        # argmin1 = np.argmin(min_)
        # print(alg_name)
        # print(min_[argmin1])
        # print(x_.iloc[argmin1].to_list())

    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    if mode != 'legend':
        patch = plt.axhline(y=sron_guess_mean,color='black', linestyle='dashed', label='SRON baseline')
        patches.append(patch)
        # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
        # patch = plt.axvline(x=cut_tail_bo, color=colors[bo_pos_in_list], linestyle='dashed', label='BO max budget')
        # patches.append(patch)
    if mode == 'best-so-far':
        ax.yaxis.set_label_position("right")
        ax.yaxis.tick_right()
        name = 'Averaged best-so-far'
        plt.ylabel(f'{name.capitalize()} $F$ value', labelpad=10, fontsize=12, rotation=270)
    else:
        name = mode
        plt.ylabel(f'{name.capitalize()} $F$ value', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-4), 10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    if mode != 'legend':
        # plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=1)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('mean')
build_plot('best-so-far')
build_plot('legend')
# print(patches)
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-mean-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-best-so-far-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-legend-crop.pdf'.

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'dynamics-leading-extensions'
    old_algs = [
        ('processedAfter-22-05-2024/umda2-dist_d0-2.csv', r'UMDA-U-PLS-Dist, $d_a$, old'),
        ('processedAfter-22-05-2024/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA old'), 
        ('processedAfter-22-05-2024/dd-ga.csv', r'DD-$(\mu/2 + \lambda), d_a$ EA, old (scaling 1000)'),
    ]
    new_algs = [
        ('processedAfter-22-05-2024/umda2-dist_d0-2_new.csv', r'UMDA-U-PLS-Dist, $d_a$, new'),
        ('processedAfter-22-05-2024/ea-simple-cross_new.csv', r'$(\mu/2 + \lambda)$ EA, new'), 
        ('processedAfter-22-05-2024/dd-ga_d0-2_scaling-100.csv', r'DD-$(\mu/2 + \lambda), d_a$ EA, new (scaling 100)'),
        ('processedAfter-22-05-2024/dd-ga_d0-3_scaling-100.csv', r'DD-$(\mu/2 + \lambda), d_b$ EA, new (scaling 100)'),
    ]
    processed_csv = old_algs + new_algs
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[2] = mpl.cm.jet(2.7/7)
    colors[5] = mpl.cm.jet(0.8)
    sron_guess = x0_ind.objf_x_samples**2

    global patches, name_to_color
    if mode != 'legend':
        patches.clear()
        name_to_color.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    cut_tail = 2100
    cut_tail_bo = 1000
    bo_pos_in_list = 0
    if mode == 'best-so-far':
        LW = 2.5
    else:
        LW = 1.5
    for i, (f, label) in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]  
        if alg_name == 'bo-sk':
            cut_tail = cut_tail_bo
            bo_pos_in_list = i
        else:
            cut_tail == 2100          
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][:cut_tail]
        y = df['mean'][:cut_tail]
        min_ = df['mean_best_so_far'][:cut_tail]
        err = df['std'][:cut_tail]/np.sqrt(df['cnt'][:cut_tail])
        name_to_color[label] = colors[i]
        if mode != 'legend':
            if mode == 'mean':
                values = y
            elif mode == 'best-so-far':
                values = min_
                err = df['std_best_so_far'][:cut_tail]
            patch, = plt.plot(x, values, c=colors[i], label=label, lw=LW)
            ax.fill_between(x, values - err, values + err, facecolor=colors[i], alpha=0.20)
            patches.append(patch)
            # print(patch.get_lw())

        # x_ = df.loc[:, 'argmin_x0':'argmin_x639']
        # argmin1 = np.argmin(min_)
        # print(alg_name)
        # print(min_[argmin1])
        # print(x_.iloc[argmin1].to_list())

    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    if mode != 'legend':
        patch = plt.axhline(y=sron_guess_mean,color='black', linestyle='dashed', label='SRON baseline')
        patches.append(patch)
        # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
        # patch = plt.axvline(x=cut_tail_bo, color=colors[bo_pos_in_list], linestyle='dashed', label='BO max budget')
        # patches.append(patch)
    if mode == 'best-so-far':
        ax.yaxis.set_label_position("right")
        ax.yaxis.tick_right()
        name = 'Averaged best-so-far'
        plt.ylabel(f'{name.capitalize()} $F$ value', labelpad=10, fontsize=12, rotation=270)
    else:
        name = mode
        plt.ylabel(f'{name.capitalize()} $F$ value', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-4), 10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    if mode != 'legend':
        # plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=1)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('mean')
build_plot('best-so-far')
build_plot('legend')
# print(patches)
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-mean-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-best-so-far-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-legend-crop.pdf'.

# %%
initial_algs_csv = [
    ('processedAfter-22-05-2024/ngopt.csv', r'NGOpt'), 
    ('processedAfter-22-05-2024/mies.csv', r'$(\mu/2, \lambda)$ MIES'), 
    ('processedAfter-22-05-2024/fastga-ng.csv', r'Integer Fast GA'), 
    ('processedAfter-22-05-2024/portfolio.csv', r'Noisy Portfolio'), 
    ('processedAfter-22-05-2024/bo-sk.csv', r'BO'),
]
leading_algs_csv = [
    ('processedAfter-22-05-2024/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
    ('processedAfter-22-05-2024/ea-simple-cross_new.csv', r'$(\mu/2 + \lambda)$ EA'),
    ('processedAfter-22-05-2024/umda.csv', r'UMDA'),
]
extended_algs_csv = [
    # ('processedAfter-22-05-2024/dd-ga.csv', r'DD-$(\mu/2 + \lambda)$ EA'),
    ('processedAfter-22-05-2024/dd-ga_d0-2_scaling-100.csv', r'DD-$(\mu/2 + \lambda), d_a$ EA'),
    ('processedAfter-22-05-2024/dd-ga_d0-3_scaling-100.csv', r'DD-$(\mu/2 + \lambda), d_b$ EA'),
    ('processedAfter-22-05-2024/umda1.csv', r'UMDA-U'),
    ('processedAfter-22-05-2024/umda2.csv', r'UMDA-U-PLS'),
    ('processedAfter-22-05-2024/umda2-dist_d0-3.csv', r'UMDA-U-PLS-Dist, $d_b$'),
]
top_alg = ('processedAfter-22-05-2024/umda2-dist_d0-2_new.csv', r'UMDA-U-PLS-Dist, $d_a$')

compared_algs = initial_algs_csv + leading_algs_csv + extended_algs_csv + [top_alg]

def build_plot(processed_csv, mode):
    basepdfname = 'dynamics-leading-extensions'
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[2] = mpl.cm.jet(2.7/7)
    colors[5] = mpl.cm.jet(0.8)
    sron_guess = x0_ind.objf_x_samples**2

    global patches, name_to_color
    if mode != 'legend':
        patches.clear()
        name_to_color.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    cut_tail = 2100
    cut_tail_bo = 1000
    bo_pos_in_list = 0
    if mode == 'best-so-far':
        LW = 2.5
    else:
        LW = 1.5
    for i, (f, label) in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]  
        if alg_name == 'bo-sk':
            cut_tail = cut_tail_bo
            bo_pos_in_list = i
        else:
            cut_tail = 2100          
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][:cut_tail]
        y = df['mean'][:cut_tail]
        min_ = df['mean_best_so_far'][:cut_tail]
        err = df['std'][:cut_tail]/np.sqrt(df['cnt'][:cut_tail])
        name_to_color[label] = colors[i]
        if mode != 'legend':
            if mode == 'mean':
                values = y
            elif mode == 'best-so-far':
                values = min_
                err = df['std_best_so_far'][:cut_tail]
            patch, = plt.plot(x, values, c=colors[i], label=label, lw=LW)
            ax.fill_between(x, values - err, values + err, facecolor=colors[i], alpha=0.20)
            patches.append(patch)
            # print(patch.get_lw())

        # x_ = df.loc[:, 'argmin_x0':'argmin_x639']
        # argmin1 = np.argmin(min_)
        # print(alg_name)
        # print(min_[argmin1])
        # print(x_.iloc[argmin1].to_list())

    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    if mode != 'legend':
        patch = plt.axhline(y=sron_guess_mean,color='black', linestyle='dashed', label='SRON baseline')
        patches.append(patch)
        # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
        # patch = plt.axvline(x=cut_tail_bo, color=colors[bo_pos_in_list], linestyle='dashed', label='BO max budget')
        # patches.append(patch)
    if mode == 'best-so-far':
        ax.yaxis.set_label_position("right")
        ax.yaxis.tick_right()
        name = 'Averaged best-so-far'
        plt.ylabel(f'{name.capitalize()} $F$ value', labelpad=10, fontsize=12, rotation=270)
    else:
        name = mode
        plt.ylabel(f'{name.capitalize()} $F$ value', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-4), 10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    if mode != 'legend':
        # plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=1)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])


build_plot(compared_algs, 'mean')
build_plot(compared_algs, 'best-so-far')
build_plot(compared_algs, 'legend')
# print(patches)
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-mean-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-best-so-far-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-leading-extensions-legend-crop.pdf'.

# %%
def build_plot():
    processed_csv = ['processed/robust-05-dd-ga.csv']
    colors = ['red']
    labels = ['Robust-DD-GA']
    sron_guess = x0_ind.objf_x_samples**2

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    CUT = 0
    for i, f in enumerate(processed_csv):
        df = pd.read_csv(f, sep=' ')
        if labels[i].startswith('Robust-'):
            x = df['population'][CUT:]
        else:
            x = df['iteration'][CUT:]
        y = df['mean'][CUT:]
        err = df['std'][CUT:]/np.sqrt(df['cnt'][CUT:])
        plt.plot(x, y, c=colors[i], label=labels[i])
        ax.fill_between(x, y - err, y + err, facecolor=colors[i], alpha=0.20)
    sron_guess_mean = np.mean(sron_guess)
    sron_guess_std = np.std(sron_guess)/np.sqrt(len(sron_guess))
    # plt.plot(x, [sron_guess_mean]*len(x), c='black', label='SRON baseline', linestyle='--')
    plt.axhline(y=sron_guess_mean,color='black',linestyle='dashed', label='SRON baseline')
    # plt.fill_between(x, [sron_guess_mean - sron_guess_std]*len(x), [sron_guess_mean + sron_guess_std]*len(x), facecolor='black', alpha=0.20)
    dd_ga_mean, dd_ga_var = 0.0007770012126629, 8.512035151360594e-05
    plt.axhline(y=dd_ga_mean,color='blue',linestyle='dashed', label='DD-GA best')
    # plt.plot(x, [dd_ga_mean]*len(x), c='blue', label='DD-GA best', linestyle='--')
    # plt.fill_between(x, [dd_ga_mean - dd_ga_var]*len(x), [dd_ga_mean + dd_ga_var]*len(x), facecolor='blue', alpha=0.20)
    plt.legend()
    plt.ylabel('Averaged min $F$ value', labelpad=-15)
    plt.xlabel('Population number')
    plt.ylim(1/2*10**(-3), 2*10**(-3))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    pdfname='dynamics-robust-05.pdf'
    fig.savefig(pdfname)
    crop_pdf(pdfname)

build_plot()
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `dynamics-robust-05-crop.pdf'.

# %%
def visualize_transmission_profiles(F, dim_reducer, x_, p: tuple, filename):
    x = np.copy(x_)
    x.sort()
    F(x, 1)
    spectral_range = F.instrument.spectral_range
    selectedfilters = F.instrument.getTransmissionMatrix(x)
    original_profiles = [selectedfilters.T[:, i] for i in range(len(x))]
    profiles = np.zeros(dim_reducer.reduced_dim, dtype=np.ndarray)
    cnt = 0
    for i in range(dim_reducer.r):
        profiles[cnt] = (original_profiles[i * (dim_reducer.m + 1)])
        cnt += 1
    for i in range(dim_reducer.r, dim_reducer.reduced_dim):
        profiles[cnt] = original_profiles[i * dim_reducer.m]
        cnt += 1
    n, m = p
    sz = len(profiles)
    selection = dim_reducer.to_reduced(x)
    fig, axs = plt.subplots(n, m)
    plt.subplots_adjust(wspace=0.05, hspace=0.05)

    def get_axs(i, j):
        if n == 1 or m == 1:
            return axs[i + j]
        return axs[i, j]

    for i in range(n):
        for j in range(m):
            profile_number = i * m + j
            if profile_number < sz:
                get_axs(i, j).plot(spectral_range, profiles[profile_number], linewidth=0.4)
            get_axs(i, j).set_xticks([])
            get_axs(i, j).set_yticks([])
            [i.set_linewidth(0.1) for i in get_axs(i, j).spines.values()]
            # get_axs(i, j).axis('off')

    colors = ['red', 'blue', 'orange', 'purple', 'cyan', 'green']
    cnt = 0
    is_first = True
    cur_color = colors[0]
    for i in range(n):
        for j in range(m):
            profile_number = i * m + j
            if profile_number < sz:
                if profile_number < sz - 1 and selection[profile_number + 1] == selection[profile_number]:
                    if is_first:
                        cur_color = colors[cnt]
                        cnt = (cnt + 1) % len(colors)
                        is_first = False
                    [i.set_linewidth(2) for i in get_axs(i, j).spines.values()]
                    [i.set_edgecolor(cur_color) for i in get_axs(i, j).spines.values()]
                elif not is_first:
                    [i.set_linewidth(2) for i in get_axs(i, j).spines.values()]
                    [i.set_edgecolor(cur_color) for i in get_axs(i, j).spines.values()]
                    is_first = True

    fig.text(0.5, 0.07, 'wavelength (nm)', ha='center')
    fig.text(0.09, 0.5, 'transmission', va='center', rotation='vertical')
    pdfname = f'{filename}.pdf'
    fig.savefig(pdfname)
    crop_pdf(pdfname)
    # plt.close()
    plt.show()


dr = create_dim_red(16)
df = pd.read_csv('archives/archive-robust-05-dd-ga.csv', sep=' ', header=None)
for k in [0, 15, 16]:
    row = df.iloc[k].tolist()
    obj_value, design = row[0], np.array([int(i) for i in row[1:]])
    print(k, obj_value)
    visualize_transmission_profiles(Fr, dr, design, (4, 4), f'transmission-{k}')
# Out:
# 0 0.0001883205455335
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `transmission-0-crop.pdf'.
# 15 0.000335348839129
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `transmission-15-crop.pdf'.
# 16 0.0003380515389139
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `transmission-16-crop.pdf'.

# %%
from myrandom import RandomEngine


def hamming_binomial_mutation(parent, mut_rate):
    num_pos = RandomEngine.sample_Binomial(len(parent), mut_rate)
    if num_pos == 0:
        num_pos = 1
    print(num_pos)
    poss = np.random.choice(len(parent), num_pos, replace=False)
    offspring_genotype = np.copy(parent)
    for pos in poss:
        offspring_genotype[pos] = np.random.randint(0, LIBRARY_SIZE)
    return offspring_genotype

# %%
import neighbors


def distance_exp():
    xrandom = utils.generate_random_solution(16, LIBRARY_SIZE)
    xrandom_nns = neighbors.generate_single_comp_changes(xrandom, 16, 32)
    for nn in xrandom_nns:
        print(1, dist_2_kirill(xrandom, nn), dist_3_kirill(xrandom, nn))
    

def distance_exp2():
    xrandom = utils.generate_random_solution(16, LIBRARY_SIZE)
    mutant = hamming_binomial_mutation(xrandom, 1/len(xrandom))
    print(dist_2_kirill(xrandom, mutant), dist_3_kirill(xrandom, mutant))


distance_exp2()
# Out:
# 1
# 0.005460933378578524 0.0284110715767983

# %%
def hamming_distance(x, y):
    return np.sum(np.where(x - y != 0, 1, 0))


def exp_step_size():
    config = utilsV3.Config()
    config.d0_method = '3'
    config.d1_method = 'kirill'
    ddga = optimizationV3.DDGA(Fr, dist_matrix_3_sorted, dist_3_kirill, config)
    ddga.configure_step_size_distribution()
    xrandom = utils.generate_random_solution(16, LIBRARY_SIZE)
    xmut = ddga.ddMutation(xrandom)
    print('min_exp_groups', 10*100*ddga.dMin, 'max_exp_groups', 15*100*ddga.dMin)
    print('mut dist 3', dist_3_kirill(xmut, xrandom), 'mut dist hamming', hamming_distance(xmut, xrandom))


exp_step_size()
# Out:
# 4.017905652392746e-06 6.107193554680426
# eps1 0.0001 eps2 5e-05
# min_exp_groups 4.017905652392746e-05 max_exp_groups 6.026858478589119e-05
# mut dist 3 0.0001422912337693226 mut dist hamming 4

# %%
def run_ea():
    config = utilsV3.Config()
    opt = optimizationV3.EASimpleWithCrossover(Fr_old, None, None, config)
    opt()

run_ea()
# Out:
# Obj value init 0: 0.004108997654556985
# Obj value init 1: 0.004041288886692197
# Obj value init 2: 0.006066024139172131
# Obj value init 3: 0.001875059504423001
# Obj value init 4: 0.0056370166609647065
# Obj value init 5: 0.001918078479344097
# Obj value init 6: 0.008223357065422586
# Obj value init 7: 0.012237445928256013
# Obj value init 8: 0.003754652465316484
# Obj value init 9: 0.0017098531156139885
# Best-so-far: 0.004108997654556985
# Best-so-far: 0.0010508534374505517
# Best-so-far: 0.0010508534374505517
# Best-so-far: 0.0009835738849293815
# Best-so-far: 0.0008476278133755595
# Best-so-far: 0.0007710840475293441
# Best-so-far: 0.0007529376254852225
# Best-so-far: 0.0007341430569436164
# Best-so-far: 0.0005782146595416859
# Best-so-far: 0.0005022340359692747
# Best-so-far: 0.0004837113314036594
# Best-so-far: 0.00041200845403533635
# Best-so-far: 0.0003287926659771002
# Best-so-far: 0.0003287926659771002
# Best-so-far: 0.0002991617926703064
# ...

# %%
reload(optimizationV3)

def run_ea():
    config = utilsV3.Config()
    config.mu_ = 10
    config.lambda_ = 20
    config.n_reps = 100
    config.folder_name = 'exp/UMDA_R' + get_datetime_str()
    FPR = create_objf_profiled(Fr, config)
    dim_red = create_dim_red(16)
    opt = optimizationV3.EASimpleWithCrossover(FPR, None, None, config)
    archive = [
        dim_red.to_reduced([60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355]),
        dim_red.to_reduced([729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60]),
        ]
    init_pop = []
    while len(init_pop) < config.mu_:
        x = archive[np.random.choice(len(archive), 1, replace=False)[0]]
        mut = opt.my_mutation(x, 10/16)
        init_pop.append(mut)
    opt(init_pop)

run_ea()
# Out:
# Best-so-far: 0.00026253496396390916
# Logging to exp/UMDA_R21-05-2024_12h11m44s/everyeval-0
# Logging to exp/UMDA_R21-05-2024_12h11m44s/bestsofar-0
# Obj value init 0: 0.00026253496396390916 n diff 12
# Best-so-far: 0.00014357807028589196
# Obj value init 1: 0.00014357807028589196 n diff 10
# Obj value init 2: 0.00033650265525265343 n diff 12
# Obj value init 3: 0.00025449668381369496 n diff 13
# Obj value init 4: 0.00041152449517114906 n diff 12
# Obj value init 5: 0.0004092584022171739 n diff 12
# Obj value init 6: 0.00021770633690836692 n diff 9
# Best-so-far: 0.0001303541582179788
# Obj value init 7: 0.0001303541582179788 n diff 11
# Obj value init 8: 0.00035524922255398503 n diff 13
# Obj value init 9: 0.0003468589648479312 n diff 13
# Best-so-far: 0.00026253496396390916 n diff 12
# Best-so-far: 0.0001303541582179788 n diff 11
# Best-so-far: 0.0001303541582179788 n diff 11
# Best-so-far: 0.00013003537906445436
# Best-so-far: 0.00012810845460344312
# ...

# %%
reload(utilsV3)
reload(optimizationV3)


def run_ea():
    config = utilsV3.Config()
    config.mu_ = 10
    config.lambda_ = 20
    config.n_reps = 100
    config.folder_name = 'exp/UMDA_R' + get_datetime_str()
    config.dd_mutation = 'umda'
    FPR = create_objf_profiled(Fr, config)
    dim_red = create_dim_red(16)
    opt = optimizationV3.DDGA(FPR, dist_matrix_2_sorted, dist_2_kirill, config)
    opt.mean = 0.1
    opt.configure_step_size_distribution()
    archive = [
        dim_red.to_reduced([60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 1838, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355, 2355]),
        dim_red.to_reduced([729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 729, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 2991, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60]),
        ]
    init_pop = []
    while len(init_pop) < config.mu_:
        x = archive[np.random.choice(len(archive), 1, replace=False)[0]]
        mut = opt.ddMutation(x)
        init_pop.append(mut)
    opt = optimizationV3.EASimpleWithCrossover(FPR, None, None, config)
    opt(init_pop)


run_ea()
# Out:
# 1.3390909280042163e-05 0.0922
# eps1 0.0001 eps2 5e-05
# Mutation step ordered 0.0001373722342186475 Mutation step made 0.10371705142491525
# Mutation step ordered 0.0008401679740274745 Mutation step made 0.08685356712079417
# Mutation step ordered 0.0007116037050514764 Mutation step made 0.13209141777693134
# Mutation step ordered 0.000525774515459764 Mutation step made 0.11328034420151958
# Mutation step ordered 0.0010811283215942775 Mutation step made 0.09281888952121674
# Mutation step ordered 0.0008257730684355097 Mutation step made 0.08335095362138611
# Mutation step ordered 0.0005102981806570245 Mutation step made 0.10235011071345526
# Mutation step ordered 0.00018247173403849727 Mutation step made 0.12305184474519136
# Mutation step ordered 0.0008405530399033047 Mutation step made 0.091057913695185
# Mutation step ordered 0.0006686782946936099 Mutation step made 0.14517131912964662
# Best-so-far: 0.010099919051904873
# Logging to exp/UMDA_R21-05-2024_12h39m11s/everyeval-0
# ...

# %%
import nevergrad as ng


best_so_far = float("inf")

def MyF(x):
    value = Fr(x, 1000)
    global best_so_far
    best_so_far = min(best_so_far, value)
    print('Best-so-far:', best_so_far)
    return value


arg1 = ng.p.Choice([i for i in range(F.instrument.filterlibrarysize)], repetitions=16)
optimizer = ng.optimizers.DoubleFastGADiscreteOnePlusOne(parametrization=arg1, budget=1000)
recommendation = optimizer.minimize(MyF)  # best value
print(recommendation.value)

# %%
reload(utilsV3)
reload(optimizationV3)


def run_umda2(instance):
    config = utilsV3.Config()
    config.mu_ = 5
    config.lambda_ = 50
    config.n_reps = 100
    config.instance = instance
    # config.folder_name = 'exp/UMDA_R' + get_datetime_str()
    config.folder_name = 'exp/parseResults1_0'
    # config.dd_mutation = 'umda'
    FPR = create_objf_profiled(Fr, config)
    opt = optimizationV3.UMDA2Dist(FPR, dist_matrix_2, dist_2_kirill, config)
    opt()

run_umda2(instance=1)
# Out:
# Best-so-far: 0.023292833888461123
# Logging to exp/parseResults1_0/everyeval-1
# Logging to exp/parseResults1_0/bestsofar-1
# Best-so-far: 0.011054703186211663
# Best-so-far: 0.0021346128899408954
# Best-so-far: 0.001248089125356281
# 0.001248089125356281
# Best-so-far: 0.000990863827327639
# Best-so-far: 0.0006977134642168859
# Best-so-far: 0.0006895104660828486
# 0.0006895104660828486
# Best-so-far: 0.0006432805472270748
# Best-so-far: 0.0005478535190209979
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[466], line 18
#      15     opt = optimizationV3.UMDA2Dist(FPR, dist_matrix_2, dist_2_kirill, config)
#      16     opt()
# ---> 18 run_umda2(instance=1)
#
# Cell In[466], line 16, in run_umda2(instance)
#      14 FPR = create_objf_profiled(Fr, config)
#      15 opt = optimizationV3.UMDA2Dist(FPR, dist_matrix_2, dist_2_kirill, config)
# ---> 16 opt()
#
# ...

# %% [markdown]
# RecombiningPortfolioDiscreteOnePlusOne
# PortfolioDiscreteOnePlusOne

# %% [markdown]
# ```python optimizationV3.py --instance 0 -a dd-ga --folder_name exp/R$(date '+%d-%m-%Y_%Hh%Mm%Ss') --n_segms 16 --budget 2110 --mu_ 10 --lambda_ 20 --n_reps 1000 --d0_method 2 --d1_method kirill --min_distance_scaling 10```

# %%
experiment_dir = 'exp/UMDA_R20-05-2024_20h55m32s/everyeval-0'
with open(os.path.join(experiment_dir, 'umda_dist.txt'), 'r') as file:

# %%
from bayes_opt import BayesianOptimization


def black_box_function(*x):
    x = list(x)
    return -x[0] ** 2 - (x[1] - 1) ** 2 + 1


black_box_function(1, 2)
# Bounded region of parameter space
pbounds = {'x': ([2, -3], [4, 3])}

optimizer = BayesianOptimization(
    f=black_box_function,
    pbounds=pbounds,
    random_state=1,
)
optimizer.maximize(
    init_points=2,
    n_iter=10,
)
# Out:
# |   iter    |  target   |     x     |
# -------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[411], line 18
#      11 pbounds = {'x': ([2, -3], [4, 3])}
#      13 optimizer = BayesianOptimization(
#      14     f=black_box_function,
#      15     pbounds=pbounds,
#      16     random_state=1,
#      17 )
# ---> 18 optimizer.maximize(
#      19     init_points=2,
#      20     n_iter=10,
#      21 )
#
# File ~/my-python-venv/lib/python3.8/site-packages/bayes_opt/bayesian_optimization.py:284, in BayesianOptimization.maximize(self, init_points, n_iter, acquisition_function, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     282 self._prime_subscriptions()
#     283 self.dispatch(Events.OPTIMIZATION_START)
# --> 284 self._prime_queue(init_points)
# ...

# %%
import numpy as np
from skopt import gp_minimize

def run_bo():
    config = utilsV3.Config()
    config.n_reps = 100
    config.folder_name = 'exp/UMDA_R' + get_datetime_str()
    FPR = create_objf_profiled(Fr, config)
    func = lambda x: FPR([int(i) for i in x], config.n_reps)
    bounds = [(0, LIBRARY_SIZE - 1) for i in range(16)]
    result = gp_minimize(func, 
                         bounds, 
                         n_initial_points = 10,
                         n_calls=20,
                         noise='gaussian',
                         model_queue_size=1,
                         verbose=True)
    
run_bo()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Best-so-far: 0.00925080701664843
# Logging to exp/UMDA_R22-05-2024_17h12m52s/everyeval-0
# Logging to exp/UMDA_R22-05-2024_17h12m52s/bestsofar-0
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.7970
# Function value obtained: 0.0093
# Current minimum: 0.0093
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1.0516
# Function value obtained: 0.0667
# Current minimum: 0.0093
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1.1476
# Function value obtained: 0.0359
# Current minimum: 0.0093
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 1.5044
# Function value obtained: 0.1209
# Current minimum: 0.0093
# ...

# %%
import scipy.stats as stats
import pandas as pd


def reorder(a, ids):
    return [a[i] for i in ids]


def get_values(f_name, BUDGET):
    f1, name = f_name
    INF = float("inf")

    df1 = pd.read_csv(f1, sep=' ')
    NINCTANCES = max(df1['cnt'].to_numpy(dtype=int))
    best_so_far = np.full(NINCTANCES, INF)
    for i in range(1, BUDGET + 1):
        values1 = df1.loc[df1['iteration'] == i].loc[:, 'eval_in_instance_0':f'eval_in_instance_{NINCTANCES-1}'].to_numpy(dtype=float)[0]
        for j in range(NINCTANCES):
            best_so_far[j] = min(best_so_far[j], values1[j])
    return best_so_far


def stat_comp(f1, fs, budget, pdfname='final-stat.pdf', styled=False, rotation=0, custom_legend=False):
    values1 = get_values(f1, budget)
    names = [f1[1]]
    x = [values1]
    stat_tests = []
    for f2 in fs:
        values2 = get_values(f2, budget)
        x.append(values2)
        stat_res = stats.mannwhitneyu(values1, values2, alternative='less', method='exact')
        stat_tests.append(stat_res)
        names.append(f2[1])
    fig = plt.figure()
    ax = plt.gca()
    sortedids = np.argsort([np.mean(d) for d in x[1:]]) + 1
    stat_tests = reorder(stat_tests, sortedids - 1)
    sortedids = np.concatenate(([0], sortedids))
    bplot = ax.boxplot(reorder(x,sortedids), notch=True, vert=True, showfliers=False, patch_artist=True, 
                    #    usermedians=[np.mean(d) for d in x], 
                       labels=reorder(names,sortedids))
    if not styled:
        plt.xticks(rotation=90)
        plt.axhline(y=np.mean(x0_ind.objf_x_samples**2), color='black', linestyle='dashed', label='SRON baseline')
        plt.legend()
    if styled:
        for patch, name in zip(bplot['boxes'], reorder(names,sortedids)):
            patch.set_facecolor(name_to_color[name])
        plt.xticks(rotation=rotation)
    if custom_legend:
        plt.legend(patches, [p.get_label() for p in patches], ncol=1)
        
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    ax.axvline(x=1.5,color='red',linestyle='dashed', label='Sep')
    plt.show()
    fig.savefig(pdfname, bbox_inches='tight')
    crop_pdf(pdfname)
    return stat_tests


stat_comp(('processedAfter-22-05-2024/umda2-dist_d0-2_new.csv', r'UMDA-U-PLS-Dist, $d_a$'), 
          [('processedAfter-22-05-2024/ea-simple-cross_new.csv', r'$(\mu/2 + \lambda)$ EA')], 
          2100,
          pdfname='final-stat-top2.pdf',
          styled=True)
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `final-stat-top2-crop.pdf'.
# [MannwhitneyuResult(statistic=233.0, pvalue=0.8155688022278919)]

# %%
initial_algs_csv = [
    ('processedAfter-22-05-2024/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
    ('processedAfter-22-05-2024/ngopt.csv', r'NGOpt'), 
    ('processedAfter-22-05-2024/mies.csv', r'$(\mu/2, \lambda)$ MIES'), 
    ('processedAfter-22-05-2024/fastga-ng.csv', r'Integer Fast GA'), 
    ('processedAfter-22-05-2024/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA'), 
    ('processedAfter-22-05-2024/portfolio.csv', r'Noisy Portfolio'), 
    ('processedAfter-22-05-2024/umda.csv', r'UMDA'),        
    # ('processedAfter-22-05-2024/bo-sk.csv', r'BO'),
]
leading_algs_csv = [
    ('processedAfter-22-05-2024/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
    ('processedAfter-22-05-2024/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA'), 
    ('processedAfter-22-05-2024/umda.csv', r'UMDA'),
]
extended_algs_csv = [
    ('processedAfter-22-05-2024/dd-ga.csv', r'DD-$(\mu/2 + \lambda)$ EA'),
    # ('processedAfter-22-05-2024/umda1.csv', r'UMDA-U'),
    ('processedAfter-22-05-2024/umda2.csv', r'UMDA-U-PLS'),
    ('processedAfter-22-05-2024/umda2-dist_d0-3.csv', r'UMDA-U-PLS-Dist, $d_b$'),
]
top_alg = ('processedAfter-22-05-2024/umda2-dist_d0-2.csv', r'UMDA-U-PLS-Dist, $d_a$')
other_algs = initial_algs_csv + extended_algs_csv
stat_comp(top_alg, other_algs, 2100)
# Out:
# [MannwhitneyuResult(statistic=94.0, pvalue=0.0017668854927644882),
#  MannwhitneyuResult(statistic=0.0, pvalue=7.254444551924842e-12),
#  MannwhitneyuResult(statistic=0.0, pvalue=7.254444551924842e-12),
#  MannwhitneyuResult(statistic=0.0, pvalue=7.254444551924842e-12),
#  MannwhitneyuResult(statistic=177.0, pvalue=0.2734115088832891),
#  MannwhitneyuResult(statistic=0.0, pvalue=7.254444551924842e-12),
#  MannwhitneyuResult(statistic=63.0, pvalue=5.2131816894596786e-05),
#  MannwhitneyuResult(statistic=4.0, pvalue=8.70533346230981e-11),
#  MannwhitneyuResult(statistic=54.0, pvalue=1.4488917617998236e-05),
#  MannwhitneyuResult(statistic=62.0, pvalue=4.552392471336224e-05)]

# %%
stat_comp(('processedBig/umda2-dist_d0-2.csv', r'UMDA-U-PLS-Dist, $d_a$'), 
          [('processedBig/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA')],
          2100,
          pdfname='final-stat-increase.pdf',
          styled=True, 
          rotation=90)
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `final-stat-increase-crop.pdf'.
# [MannwhitneyuResult(statistic=3951.0, pvalue=0.005101331015197491)]

# %%
def doStatComp():
    initial_algs_csv = [
        ('processedAfter-22-05-2024/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
        ('processedAfter-22-05-2024/ngopt.csv', r'NGOpt'), 
        ('processedAfter-22-05-2024/mies.csv', r'$(\mu/2, \lambda)$ MIES'), 
        ('processedAfter-22-05-2024/fastga-ng.csv', r'Integer Fast GA'), 
        # ('processedAfter-22-05-2024/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA'), 
        ('processedAfter-22-05-2024/portfolio.csv', r'Noisy Portfolio'), 
        ('processedAfter-22-05-2024/umda.csv', r'UMDA'),        
        ('processedAfter-22-05-2024/bo-sk.csv', r'BO'),
    ]
    leading_algs_csv = [
        ('processedAfter-22-05-2024/ea-simple.csv', r'$(\mu + \lambda)$ EA'),
        # ('processedAfter-22-05-2024/ea-simple-cross.csv', r'$(\mu/2 + \lambda)$ EA'), 
        ('processedAfter-22-05-2024/ea-simple-cross_new.csv', r'$(\mu/2 + \lambda)$ EA'),
        ('processedAfter-22-05-2024/umda.csv', r'UMDA'),
    ]
    extended_algs_csv = [
        # ('processedAfter-22-05-2024/dd-ga.csv', r'DD-$(\mu/2 + \lambda)$ EA'),
        ('processedAfter-22-05-2024/dd-ga_d0-2_scaling-100.csv', r'DD-$(\mu/2 + \lambda), d_a$ EA'),
        # ('processedAfter-22-05-2024/dd-ga_d0-3_scaling-100.csv', r'DD-$(\mu/2 + \lambda), d_b$ EA'),
        ('processedAfter-22-05-2024/umda1.csv', r'UMDA-U'),
        ('processedAfter-22-05-2024/umda2.csv', r'UMDA-U-PLS'),
        ('processedAfter-22-05-2024/umda2-dist_d0-3.csv', r'UMDA-U-PLS-Dist, $d_b$'),
    ]

    top_alg = ('processedAfter-22-05-2024/umda2-dist_d0-2_new.csv', r'UMDA-U-PLS-Dist, $d_a$')
    processed_csv = leading_algs_csv + extended_algs_csv

    stats = stat_comp(top_alg, 
              processed_csv,
              2100,
              pdfname='final-stat.pdf',
              styled=True,
              rotation=90,
              custom_legend=False)
    print(*stats, sep='\n')
    
doStatComp()
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `final-stat-crop.pdf'.
# MannwhitneyuResult(statistic=349.0, pvalue=0.9999921768287579)
# MannwhitneyuResult(statistic=233.0, pvalue=0.8155688022278919)
# MannwhitneyuResult(statistic=145.0, pvalue=0.07085251537057889)
# MannwhitneyuResult(statistic=117.0, pvalue=0.012233861341565554)
# MannwhitneyuResult(statistic=107.0, pvalue=0.0056033836442019435)
# MannwhitneyuResult(statistic=106.0, pvalue=0.005157018766343135)
# MannwhitneyuResult(statistic=3.0, pvalue=5.078111186347389e-11)

# %%
reload(optimizationV3)


def run_stat_exp(inds):
    config = utilsV3.Config()
    config.max_samples = 1000
    opt = optimizationV3.UMDA2DistRobust(Fr, None, None, config)
    robust_best_pos = opt.select_robust_best(inds)
    print(robust_best_pos, inds[robust_best_pos].obj_value())
    return robust_best_pos

# %%
inds = [optimizationV3.Individual(Fr, utils.generate_random_solution(16, LIBRARY_SIZE), None) for _ in range(10)]
for ind in inds:
    ind.add_samples(100)
    print(ind.obj_value())
# Out:
# 0.04325684227569242
# 0.12274966921009157
# 0.006384916726641698
# 0.003966782954805938
# 0.06090594601321274
# 0.024968894824802426
# 0.02884236848606679
# 0.04652124500553109
# 0.030642950208328017
# 0.03612200666203546

# %%
pos = run_stat_exp(inds)
# Out:
# 0 0.12274966921009157

# %%
for ind in inds:
    print(len(ind.objf_x_samples), ind.obj_value())
ind = inds.pop(pos)
print('Removed:')
print(len(ind.objf_x_samples), ind.obj_value())
# Out:
# 100 0.12274966921009157
# Removed:
# 100 0.12274966921009157

# %%
optimizationV3.WelchTTestPvalue(ind, inds[0])
# Out:
# 0.0005271557498304003

# %%
import parseResults4
reload(parseResults4)


def doParse4(dir):
    config = utilsV3.Config()
    config.d0_method = '2'
    config.d1_method = 'kirill'
    config.n_segms = 16
    TH_DIST = 0.05 # d0_method = '2', d1_method = 'kirill'
    TH_OBJ = 0.0003 # sron_guess_obj / 2

    designs, obj_values = parseResults4.read_data_frame(dir, TH_OBJ)
    print('Locating independent set...', flush=True)
    parseResults4.locate_independent_set(dir, obj_values, designs, config, dist_2_kirill, TH_DIST)


doParse4('exp/tmp-root-3')
# Out:
# IOHprofiler_f25_DIM640.dat
# IOHprofiler_f25_DIM640.dat
# Locating independent set...
# 458

# %%
import parseResults1
reload(parseResults1)

parseResults1.main('exp/tmp-root-3')
# Out:
# /home/kirill/Projects/PhD/Files/Leiden/SRON/CS-Journal/code/SRON/parseResults1.py:60: RuntimeWarning: Mean of empty slice
#   print(dir, iteration, np.mean(vals), np.std(vals), mean_best_so_far, std_best_so_far, np.nanmean(diversities), np.nanstd(diversities), len(vals), *instance_cur_value, file=file)
# /home/kirill/my-python-venv/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
def process_file(filepath):
    new, old = [], []
    with open(filepath, 'r') as file:
        for line in file:
            if line.startswith('Old'):
                spl = line.split(' ')
                old.append(float(spl[1]))
                new.append(float(spl[3]))
    return np.array(new), np.array(old)

new, old = process_file('exp/tmp-root-3/resampled-stdout.txt')
changes = np.abs(new - old) / old * 100
print(len(new))
print(np.mean(changes), np.std(changes))
print(sum(new < old)/len(old)*100)
# Out:
# 114
# 6.273770864088487 4.181824976722677
# 9.649122807017543

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'diversity'
    processed_csv = [
        ('processedAfter-22-05-2024/dd-ga.csv', r'DD-$(\mu/2 + \lambda)$ EA'),
        ('processedBig/umda2-dist_d0-2.csv', r'UMDA-U-PLS-Dist, $d_a$'),
    ]
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[2] = mpl.cm.jet(2.7/7)

    global patches, name_to_color
    if mode != 'legend':
        patches.clear()
        name_to_color.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    cut_tail = 2100
    if mode == 'diversity':
        LW = 2.5
    else:
        LW = 1.5
    for i, (f, label) in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]          
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][:cut_tail]
        y = df['mean_diversity'][:cut_tail]
        err = df['std_diversity'][:cut_tail]/np.sqrt(df['cnt'][:cut_tail])
        name_to_color[label] = colors[i]
        if mode != 'legend':
            values = y
            patch, = plt.plot(x, values, c=colors[i], label=label, lw=LW)
            ax.fill_between(x, values - err, values + err, facecolor=colors[i], alpha=0.20)
            patches.append(patch)
            # print(patch.get_lw())
    plt.ylabel(f'Mean Diversity', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-2), 2*10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    if mode != 'legend':
        plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=1)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('diversity')
build_plot('legend')
# print(patches)
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `diversity-diversity-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `diversity-legend-crop.pdf'.

# %%
import pandas as pd
import os
import subprocess


def build_plot(mode):
    basepdfname = 'diversity'
    processed_csv = [
        ('processedAfter-22-05-2024/dd-ga_d0-2_scaling-100.csv', r'DD-$(\mu/2 + \lambda), d_a$ EA'),
        # ('processedAfter-22-05-2024/dd-ga_d0-3_scaling-100.csv', r'DD-$(\mu/2 + \lambda), d_b$ EA'),
        ('processedAfter-22-05-2024/ea-simple-cross_new.csv', r'$(\mu/2 + \lambda)$ EA'),
        ('processedAfter-22-05-2024/umda2-dist_d0-2_new.csv', r'UMDA-U-PLS-Dist, $d_a$'),
    ]
    colors = mpl.cm.jet(np.linspace(0, 1, len(set(processed_csv))))
    # colors[2] = mpl.cm.jet(2.7/7)

    global patches, name_to_color
    if mode != 'legend':
        patches.clear()
        name_to_color.clear()

    fig = plt.figure()
    ax = plt.gca()
    ax.set_yscale('log')
    cut_tail = 2100
    if mode == 'diversity':
        LW = 2.5
    else:
        LW = 1.5
    for i, (f, label) in enumerate(processed_csv):
        alg_name = os.path.basename(f).split('.')[0]          
        df = pd.read_csv(f, sep=' ')
        x = df['iteration'][:cut_tail]
        y = df['mean_diversity'][:cut_tail]
        err = df['std_diversity'][:cut_tail]/np.sqrt(df['cnt'][:cut_tail])
        name_to_color[label] = colors[i]
        if mode != 'legend':
            values = y
            patch, = plt.plot(x, values, c=colors[i], label=label, lw=LW)
            ax.fill_between(x, values - err, values + err, facecolor=colors[i], alpha=0.20)
            patches.append(patch)
            # print(patch.get_lw())
    plt.ylabel(f'Mean Diversity', labelpad=-20, fontsize=12)
    plt.xlabel('$F$ evaluation number')
    plt.ylim(10**(-2), 2*10**(-1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    if mode != 'legend':
        plt.legend()
        pdfname = f'{basepdfname}-{mode}.pdf'
    else:
        ax.set_axis_off()
        for p in patches:
            p.set_lw(2)
        plt.legend(patches, [p.get_label() for p in patches], ncol=1)
        pdfname = f'{basepdfname}-legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])



build_plot('diversity')
build_plot('legend')
# print(patches)
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `diversity-diversity-crop.pdf'.
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `diversity-legend-crop.pdf'.

# %%
def doVisSolutionBoxPlots():
    design_ids = []
    nums = []
    designs_data = []
    with open('processedBig/results_umda2-dist_d0-2/top-umda2-dist_d0-2.csv', 'r') as file:
        for row in file:
            sp = row.split(' ')
            d0 = int(sp[0])
            d1 = int(sp[1])
            d2 = np.array([float(i) for i in sp[2:]])
            designs_data.append([d0, d1, d2])
            design_ids.append(d0)
            nums.append(d1)

    # id_x0 = len(designs_data)
    # n_x0 = len(set(x0))
    # design_ids.append(id_x0)
    # nums.append(n_x0)
    # designs_data.append([id_x0, n_x0, x0_ind.objf_x_samples])

    Objective = lambda x: np.mean(x**2)
    # Objective = lambda x: np.mean(x)

    fig = plt.figure()
    ax = plt.gca()
    design_ids = np.array(design_ids)
    designs_data.sort(key=lambda d: Objective(d[2]))
    x = []
    ticks = []
    colors = []
    colors_lib = mpl.cm.jet(np.linspace(0, 1, len(set(nums))))
    # colors_lib[2] = mpl.cm.jet(0.6)
    unique_nums = list(set(nums))
    unique_nums.sort()
    n_to_color = {}
    for n, c in zip(unique_nums, colors_lib):
        n_to_color[n] = c
    # n_to_color = {11: 'green', 12: 'blue', 13: 'purple',
        # 14: 'orange', 15: 'red', 16: 'black'}
    color_to_bplot_number = {}
    num_to_bplot_number = {}
    cnt = 0
    for d in designs_data:
        ticks.append(d[0] + 1)
        x.append(d[2]**2)
        colors.append(n_to_color[d[1]])
        # color_to_bplot_number[n_to_color[d[1]]] = cnt
        num_to_bplot_number[d[1]] = cnt
        cnt += 1
    bplot = ax.boxplot(x, vert=True, showfliers=False, patch_artist=True, usermedians=[Objective(d[2]) for d in designs_data])
    cnt = 0
    for color in colors:
        bplot['boxes'][cnt].set_facecolor(color)
        # plt.setp(bplot['boxes'][cnt], color=color)
        # plt.setp(bplot['caps'][2*cnt], color=color)
        # plt.setp(bplot['caps'][2*cnt+1], color=color)
        # plt.setp(bplot['whiskers'][2*cnt], color=color)
        # plt.setp(bplot['whiskers'][2*cnt+1], color=color)

        cnt += 1
    bplot_boxes = []
    legends = []
    for i in n_to_color.keys():
        num = num_to_bplot_number[i]
        n_diff_filters = designs_data[num][1]
        bplot_boxes.append(bplot['boxes'][num])
        legends.append(f'{n_diff_filters} diff filters')
    plt.xticks([i for i in range(1, len(x) + 1)], ticks, fontsize=6)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    # ax.legend(bplot_boxes, legends, loc='upper center', bbox_to_anchor=(0.6, 1.1), ncol=4)
    fig.text(0.5, 0.04, 'Design ID', ha='center')
    # fig.text(0.04, 0.5, 'Performance in 1K runs', va='center', rotation='vertical')
    ax.grid()
    fig.savefig('box-plots-2.pdf')


doVisSolutionBoxPlots()

# %%
def doVisSolutions(filename):
    pdfname = 'sorted-solutions.pdf'
    design_ids = []
    nums = []
    designs_data = []
    color = name_to_color['UMDA-U-PLS-Dist, $d_a$']
    
    with open(filename, 'r') as file:
        for row in file:
            sp = row.split(' ')
            d0 = int(sp[0])
            d1 = int(sp[1])
            d2 = np.array([float(i) for i in sp[2:]])
            designs_data.append([d0, d1, d2])
            design_ids.append(d0)
            nums.append(d1)
    Objective = lambda x: np.mean(x**2)
    designs_data.sort(key=lambda d: Objective(d[2]))
    print([(d[0], Objective(d[2])) for d in designs_data])
    fig = plt.figure()
    ax = plt.gca()    
    ax.set_yscale('log')
    objective_values = np.array([Objective(d[2]) for d in designs_data])
    std_dev = np.array([np.std(d[2]**2) for d in designs_data])
    x = np.arange(len(objective_values))
    plt.plot(x, objective_values, c=color, label='High-performing solutions', lw=2)
    ax.fill_between(x, objective_values - std_dev, objective_values + std_dev, facecolor=color, alpha=0.20)
    plt.xticks(np.arange(0, 115, 10))
    plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')
    plt.ylabel(r'$F\! \left(\boldsymbol{x^{(i)}} \right)$', rotation=270, labelpad=25)
    plt.xlabel(r'Number of solution $i$')
    sron_mean = np.mean(x0_ind.objf_x_samples**2)
    sron_std = np.std(x0_ind.objf_x_samples**2)
    ax.axhline(y=sron_mean,color='black',linestyle='dashed', label='SRON baseline')
    # ax.fill_between(x, sron_mean - sron_std, sron_mean + sron_std, facecolor='black', alpha=0.20)
    ax.yaxis.set_label_position("right")
    plt.legend()
    fig.savefig(pdfname, bbox_inches='tight')
    subprocess.run(['pdfcrop', pdfname])


doVisSolutions('processedBig/results_umda2-dist_d0-2/top-umda2-dist_d0-2.csv')
# Out:
# [(0, 0.00018494292954104993), (4, 0.00018875394066839198), (1, 0.00018933099276045908), (2, 0.00018995402783451517), (5, 0.00020265628113406016), (8, 0.00020376631926638495), (3, 0.00020593070081970164), (7, 0.00020941913441199108), (6, 0.0002095317018925523), (16, 0.00022691306964885456), (12, 0.00022840637343691747), (9, 0.00022943406665255979), (11, 0.00023412971473383716), (18, 0.0002369946076287957), (19, 0.00023707159142466322), (20, 0.00023723574069846583), (21, 0.00023857199010846072), (13, 0.00023915329291236508), (28, 0.00023967902809608939), (27, 0.00024119361844408414), (22, 0.00024153691198671465), (23, 0.00024208598125540038), (33, 0.00024248969979407398), (15, 0.00024333874480462613), (14, 0.00024384686149358164), (71, 0.00024447692123040536), (32, 0.0002446036739130881), (10, 0.00024519254375689534), (25, 0.0002457644658130678), (30, 0.0002466650333425951), (58, 0.0002495960047847396), (52, 0.0002499089641867581), (17, 0.00025131807607432614), (42, 0.00025337206783719
# ...

# %%
def visualize_transmission_profiles(F, dim_reducer, x_, p: tuple, filename):
    x = np.copy(x_)
    x.sort()
    F(x, 1)
    spectral_range = F.instrument.spectral_range
    selectedfilters = F.instrument.getTransmissionMatrix(x)
    original_profiles = [selectedfilters.T[:, i] for i in range(len(x))]
    profiles = np.zeros(dim_reducer.reduced_dim, dtype=np.ndarray)
    cnt = 0
    for i in range(dim_reducer.r):
        profiles[cnt] = (original_profiles[i * (dim_reducer.m + 1)])
        cnt += 1
    for i in range(dim_reducer.r, dim_reducer.reduced_dim):
        profiles[cnt] = original_profiles[i * dim_reducer.m]
        cnt += 1
    n, m = p
    sz = len(profiles)
    selection = dim_reducer.to_reduced(x)
    fig, axs = plt.subplots(n, m)
    plt.subplots_adjust(wspace=0.05, hspace=0.05)

    def get_axs(i, j):
        if n == 1 or m == 1:
            return axs[i + j]
        return axs[i, j]

    for i in range(n):
        for j in range(m):
            profile_number = i * m + j
            if profile_number < sz:
                get_axs(i, j).plot(spectral_range, profiles[profile_number], linewidth=0.4)
            get_axs(i, j).set_xticks([])
            get_axs(i, j).set_yticks([])
            [i.set_linewidth(0.1) for i in get_axs(i, j).spines.values()]
            # get_axs(i, j).axis('off')

    colors = ['red', 'blue', 'orange', 'purple', 'cyan', 'green']
    cnt = 0
    is_first = True
    cur_color = colors[0]
    for i in range(n):
        for j in range(m):
            profile_number = i * m + j
            if profile_number < sz:
                if profile_number < sz - 1 and selection[profile_number + 1] == selection[profile_number]:
                    if is_first:
                        cur_color = colors[cnt]
                        cnt = (cnt + 1) % len(colors)
                        is_first = False
                    [i.set_linewidth(2) for i in get_axs(i, j).spines.values()]
                    [i.set_edgecolor(cur_color) for i in get_axs(i, j).spines.values()]
                elif not is_first:
                    [i.set_linewidth(2) for i in get_axs(i, j).spines.values()]
                    [i.set_edgecolor(cur_color) for i in get_axs(i, j).spines.values()]
                    is_first = True

    fig.text(0.5, 0.07, 'wavelength (nm)', ha='center')
    fig.text(0.09, 0.5, 'transmission', va='center', rotation='vertical')
    pdfname = f'{filename}.pdf'
    fig.savefig(pdfname)
    crop_pdf(pdfname)
    # plt.close()
    plt.show()


def doVisProfiles():
    dr = create_dim_red(16)
    df = pd.read_csv('processedBig/results_umda2-dist_d0-2/archive.csv', sep=' ', header=None)
    for k in [0, 4, 1]:
        row = df.iloc[k].tolist()
        obj_value, design = row[0], np.array([int(i) for i in row[1:]])
        print(k, obj_value, len(set(design)))
        visualize_transmission_profiles(Fr, dr, design, (4, 4), f'transmission-{k}')


doVisProfiles()
# Out:
# 0 0.0001704647013529 16
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `transmission-0-crop.pdf'.
# 4 0.000185296625746 16
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `transmission-4-crop.pdf'.
# 1 0.0001768075561706 16
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `transmission-1-crop.pdf'.

# %%
def doBuildUmdaDistr(filename):
    with open(filename, 'r') as file:
        for i, line in enumerate(file):
            if i % 2 == 0:
                continue
            p = [float(v) for v in line.split(' ')]
            fig, ax = plt.subplots()
            ax.plot(p)


doBuildUmdaDistr('umda_distr.txt')
# Out:
# /tmp/ipykernel_2790869/2530136639.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import plotly.graph_objects as go



def build_heatmap(filewithmatrix):
    fig = plt.figure()
    df = pd.read_csv(filewithmatrix, sep=' ', header=None)
    M = df.to_numpy()
    M[M < 0.05/32/32] = 0
    M[M >= 0.05/32/32] = 1
    print(1 - M.sum()/32/32)
    ax = sns.heatmap(M, cmap='jet', cbar=False, square=True, linewidths=0.0)
    # colors = ax.collections[0].get_facecolors()
    # ax.collections[0].set_edgecolors(colors)
    filename = os.path.basename(filewithmatrix)
    name = os.path.splitext(filename)[0]
    ax.set_yticklabels([f'{i}' for i in np.arange(1, 33, 2)], rotation=0)
    ax.set_xticks(np.arange(1, 33, 2)-0.5)
    ax.set_xticklabels([f'{i}' for i in np.arange(1, 33, 2)], rotation=0)
    pdfname = f'{name}.pdf'
    fig.savefig(pdfname, dpi=1000, bbox_inches='tight')
    crop_pdf(pdfname)



def build_surface(filewithmatrix):
    df = pd.read_csv(filewithmatrix, sep=' ')
    Z = df.to_numpy()    
    fig = go.Figure(data=[go.Surface(z=Z)])
    # fig.update_layout(title='Sphere', autosize=False,
    #               scene_camera_eye=dict(x=1.87, y=0.88, z=-0.64),
    #               width=500, height=500,
    #               margin=dict(l=65, r=50, b=65, t=90))

    fig.show()


def create_legend():
    fig = plt.figure()
    ax = plt.gca()
    patch0 = mpl.patches.Patch(color=mpl.cm.jet(0))
    patch1 = mpl.patches.Patch(color=mpl.cm.jet(0.99))
    plt.legend([patch0, patch1], [r'pvalue $< \dfrac{0.05}{1024}$ (Different)', r'pvalue $\geq \dfrac{0.05}{1024}$ (Same)'], ncol=2, fancybox=True, loc="center", bbox_to_anchor=(0,1))
    ax.set_axis_off()
    plt.tight_layout()
    pdfname = 'groups_legend.pdf'
    fig.savefig(pdfname, bbox_inches='tight')
    crop_pdf(pdfname)

# %%
create_legend()

build_heatmap('./processed_pvalues/ea_mut.csv')
build_heatmap('./processed_pvalues/ea_mut_3.csv')
build_heatmap('./processed_pvalues/hamming_mut.csv')
# Out:
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `groups_legend-crop.pdf'.
# 0.435546875
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `ea_mut-crop.pdf'.
# 0.1494140625
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `ea_mut_3-crop.pdf'.
# 0.181640625
# PDFCROP 1.42, 2023/04/15 - Copyright (c) 2002-2023 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `hamming_mut-crop.pdf'.

# %%
MannwhitneyuResult(statistic=333.0, pvalue=0.9999224422617558)
MannwhitneyuResult(statistic=176.0, pvalue=0.26454846145323485)
MannwhitneyuResult(statistic=94.0, pvalue=0.0017668854927644882)
MannwhitneyuResult(statistic=54.0, pvalue=1.4488917617998236e-05)
MannwhitneyuResult(statistic=62.0, pvalue=4.552392471336224e-05)
MannwhitneyuResult(statistic=63.0, pvalue=5.2131816894596786e-05)
MannwhitneyuResult(statistic=0.0, pvalue=7.254444551924842e-12)

MannwhitneyuResult(statistic=349.0, pvalue=0.9999921768287579)
MannwhitneyuResult(statistic=233.0, pvalue=0.8155688022278919)
MannwhitneyuResult(statistic=145.0, pvalue=0.07085251537057889)
MannwhitneyuResult(statistic=117.0, pvalue=0.012233861341565554)
MannwhitneyuResult(statistic=107.0, pvalue=0.0056033836442019435)
MannwhitneyuResult(statistic=106.0, pvalue=0.005157018766343135)
MannwhitneyuResult(statistic=3.0, pvalue=5.078111186347389e-11)

# %%
mutator_d2 = utilsV3.DDMutationEA(dist_2_kirill, dist_matrix_2_sorted)

# %%
import utilsV3

x = utils.generate_random_solution(16, LIBRARY_SIZE)
dMin = utilsV3.findExtremeDist(x, dist_matrix_2_sorted, dist_2_kirill, 'min', mutator_d2, '2', 'kirill')
dMax = utilsV3.findExtremeDist(x, dist_matrix_2_sorted, dist_2_kirill, 'max', mutator_d2, '2', 'kirill')
gamma = utilsV3.findDistGamma(100*dMin, dMax)
# Out:
# 1.3390909280042163e-05 0.0922
# eps1 0.0001 eps2 5e-05

# %%
rv_to_dist = lambda gamma_, s: np.sqrt(-np.log(1 - s)) / gamma_

print(100*dMin)
print(1000*dMin)
print(15*100*dMin)
print(dMax)
rv_to_dist(gamma, 0.1)
# Out:
# 1.3390909280042163e-05
# 0.00013390909280042163
# 0.00020086363920063244
# 0.0922
# 0.0008313023794333609

# %%
x = np.linspace(0.0001, 1-5e-05, 100)
y = []
err = []
for s in x:
    d = rv_to_dist(gamma, s)
    M = 10
    ys = np.zeros(M)
    for i in range(M):
        parent = utils.generate_random_solution(16, LIBRARY_SIZE)
        mutant = mutator_d2.mutation(parent, d)
        ys[i] = abs(dist_2_kirill(parent, mutant) - d)
    y.append(np.mean(ys))
    err.append(np.std(ys))
    
print(y)
print(err)
# Out:
# [1.2850027804033544e-07, 1.616475012893026e-07, 1.53819216902639e-07, 2.8088177754315505e-06, 5.023921372194952e-08, 1.7917598772185587e-07, 1.274365394905632e-07, 1.0827291074975575e-05, 7.299119285861245e-08, 4.184000078309713e-08, 5.3313610949871566e-08, 5.429389113720566e-07, 1.530633587517975e-07, 2.0486329456383295e-08, 1.2929586683005193e-07, 1.8226802162069066e-06, 4.276626311356183e-08, 6.638436175071538e-08, 2.5439013020926714e-08, 1.802239704298478e-07, 5.376433180187545e-08, 6.94936982773356e-08, 2.5132227701618605e-06, 4.9333368340800934e-08, 9.881864961808553e-08, 4.4132621490481155e-08, 4.6148939248768364e-08, 3.7781433948145396e-08, 6.177770456722298e-08, 5.338636995221025e-08, 1.250619725693628e-06, 2.378763685347528e-08, 5.623334124668644e-08, 4.707762040062624e-08, 7.007149886721805e-08, 4.680783825261603e-08, 1.0057265233918977e-07, 2.993566942171774e-08, 4.685118289386031e-08, 6.811636611807337e-08, 6.61442807191135e-06, 6.044467708511865e-08, 7.852033685622032e-
# ...

# %%
print(x)
for s in x:
    print(rv_to_dist(gamma, s))
# Out:
# [1.00000000e-04 1.01994949e-02 2.02989899e-02 3.03984848e-02
#  4.04979798e-02 5.05974747e-02 6.06969697e-02 7.07964646e-02
#  8.08959596e-02 9.09954545e-02 1.01094949e-01 1.11194444e-01
#  1.21293939e-01 1.31393434e-01 1.41492929e-01 1.51592424e-01
#  1.61691919e-01 1.71791414e-01 1.81890909e-01 1.91990404e-01
#  2.02089899e-01 2.12189394e-01 2.22288889e-01 2.32388384e-01
#  2.42487879e-01 2.52587374e-01 2.62686869e-01 2.72786364e-01
#  2.82885859e-01 2.92985354e-01 3.03084848e-01 3.13184343e-01
#  3.23283838e-01 3.33383333e-01 3.43482828e-01 3.53582323e-01
#  3.63681818e-01 3.73781313e-01 3.83880808e-01 3.93980303e-01
#  4.04079798e-01 4.14179293e-01 4.24278788e-01 4.34378283e-01
#  4.44477778e-01 4.54577273e-01 4.64676768e-01 4.74776263e-01
#  4.84875758e-01 4.94975253e-01 5.05074747e-01 5.15174242e-01
#  5.25273737e-01 5.35373232e-01 5.45472727e-01 5.55572222e-01
#  5.65671717e-01 5.75771212e-01 5.85870707e-01 5.95970202e-01
# ...

# %%
def tmp():
    parent = np.array([1, 2, 3, 4, 5])
    mutant = np.array([2, 1, 3, 4, 5])
    print(sum(parent != mutant))
    
tmp()
# Out:
# 2

# %%
def my_lap_inv_exp(d0_type):
    d1_type = 'kirill'
    if d0_type == '2' and d1_type == 'kirill':
        dist = dist_2_kirill
        matrix_sorted = dist_matrix_2_sorted
    if d0_type == '3' and d1_type == 'kirill':
        dist = dist_3_kirill
        matrix_sorted = dist_matrix_3_sorted
    mutator = utilsV3.DDMutationEA(dist, matrix_sorted)
    x = utils.generate_random_solution(16, LIBRARY_SIZE)
    dMin = utilsV3.findExtremeDist(x, matrix_sorted, dist, 'min', mutator, d0_type, d1_type)
    dMax = utilsV3.findExtremeDist(x, matrix_sorted, dist, 'max', mutator, d0_type, d1_type)
    dMinWafe = 100*dMin
    gamma = utilsV3.findDistGamma(dMinWafe, dMax)
    rv_to_dist = lambda gamma_, s: np.sqrt(-np.log(1 - s)) / gamma_
    x = np.linspace(0.0001, 1-5e-05, 100)
    y = []
    err = []
    with open(f'log_dist_{d0_type}', 'w') as file:
        for s in x:
            d = rv_to_dist(gamma, s)
            M = 10
            ys = np.zeros(M)
            hs = np.zeros(M)
            for i in range(M):
                parent = utils.generate_random_solution(16, LIBRARY_SIZE)
                mutant = mutator_d2.mutation(parent, d)
                ys[i] = abs(dist_2_kirill(parent, mutant) - d)
                hs[i] = sum(parent != mutant)
            y.append(np.mean(ys))
            err.append(np.std(ys))
            print('step size to', d, 'with mean error', y[-1], 'std', err[-1], 'hamming mean', np.mean(hs), 'hamming std', np.std(hs), file=file)
    return y, err


y2, err2 = my_lap_inv_exp('2')
y3, err3 = my_lap_inv_exp('3')
# Out:
# 1.3390909280042163e-05 0.0922
# eps1 0.0001 eps2 5e-05
# 4.017905652392746e-06 6.107193554680426
# eps1 0.0001 eps2 5e-05

# %%
def doexp(d0_type):
    d1_type = 'kirill'
    if d0_type == '2' and d1_type == 'kirill':
        dist = dist_2_kirill
        matrix_sorted = dist_matrix_2_sorted
        y, err = y2, err2
    if d0_type == '3' and d1_type == 'kirill':
        dist = dist_3_kirill
        matrix_sorted = dist_matrix_3_sorted
        y, err = y3, err3
    mutator = utilsV3.DDMutationEA(dist, matrix_sorted)
    x = utils.generate_random_solution(16, LIBRARY_SIZE)
    dMin = utilsV3.findExtremeDist(x, matrix_sorted, dist, 'min', mutator, d0_type, d1_type)
    dMax = utilsV3.findExtremeDist(x, matrix_sorted, dist, 'max', mutator, d0_type, d1_type)
    dMinWafe = 100*dMin
    gamma = utilsV3.findDistGamma(dMinWafe, dMax)
    rv_to_dist = lambda gamma_, s: np.sqrt(-np.log(1 - s)) / gamma_
    x = np.linspace(0.0001, 1-5e-05, 100)
    y_div, err_div = np.zeros(len(x)), np.zeros(len(x))
    for i,s in enumerate(x):
        S = rv_to_dist(gamma, s)
        y_div[i] = y[i]/S
        err_div[i] = err[i]/(S**2)
    return y_div, err_div

# %%
print(np.median(y2), np.median(err2))
print(np.max(y3), np.max(err3))

y2_div, err2_div = doexp('2')
y3_div, err3_div = doexp('3')
print(np.median(y2_div), np.median(y3_div))
print(np.max(y2_div), np.max(err2_div))
print(np.max(y3_div), np.max(err3_div))
# Out:
# 7.356207571106165e-08 8.010871649901275e-08
# 1.5462489055440203e-05 4.598453866280813e-05
# 1.3390909280042163e-05 0.0922
# eps1 0.0001 eps2 5e-05
# 4.017905652392746e-06 6.107193554680426
# eps1 0.0001 eps2 5e-05
# 3.999349596314525e-05 0.0001268294940049601
# 0.02054628428265763 120.6301857988314
# 0.04209622648320271 9925.007161861104

# %%
def doexp2(d0_type):
    d1_type = 'kirill'
    if d0_type == '2' and d1_type == 'kirill':
        dist = dist_2_kirill
        matrix_sorted = dist_matrix_2_sorted
        y, err = y2, err2
    if d0_type == '3' and d1_type == 'kirill':
        dist = dist_3_kirill
        matrix_sorted = dist_matrix_3_sorted
        y, err = y3, err3
    mutator = utilsV3.DDMutationEA(dist, matrix_sorted)
    x = utils.generate_random_solution(16, LIBRARY_SIZE)
    dMin = utilsV3.findExtremeDist(x, matrix_sorted, dist, 'min', mutator, d0_type, d1_type)
    dMax = utilsV3.findExtremeDist(x, matrix_sorted, dist, 'max', mutator, d0_type, d1_type)
    dMinWafe = 100*dMin
    gamma = utilsV3.findDistGamma(dMinWafe, dMax)
    step_to_dist = lambda gamma_, s: np.sqrt(-np.log(1 - s)) / gamma_
    dist_to_step = lambda gamma_, d: 1 - np.exp(-gamma_**2 * d**2)
    mean = 0.1
    D = myrnd.RandomEngine.TruncatedExponentialDistribution().build(mean, 1e-9)
    return D.cdf(dist_to_step(gamma, 10*dMinWafe))

print(doexp2('2'))
print(doexp2('3'))
# Out:
# 1.3390909280042163e-05 0.0922
# eps1 0.0001 eps2 5e-05
# 37.14531427310117
# 4.017905652392746e-06 6.107193554680426
# eps1 0.0001 eps2 5e-05
# 40.54995347028084

# %%
# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='Time [s]', ylabel='Voltage [mV]',
       title='About as simple as it gets, folks')

import tikzplotlib
tikzplotlib.save("figure.pgf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 12
#       8 ax.set(xlabel='Time [s]', ylabel='Voltage [mV]',
#       9        title='About as simple as it gets, folks')
#      11 import tikzplotlib
# ---> 12 tikzplotlib.save("figure.pgf")
#
# File ~/my-python-venv/lib/python3.8/site-packages/tikzplotlib/_save.py:262, in save(filepath, encoding, *args, **kwargs)
#     252 def save(filepath: str | Path, *args, encoding: str | None = None, **kwargs):
#     253     """Same as `get_tikz_code()`, but actually saves the code to a file.
#     254
#     255     :param filepath: The file to which the TikZ output will be written.
#    (...)
#     260     :returns: None
#     261     """
# --> 262     code = get_tikz_code(*args, filepath=filepath, **kwargs)
#     263     with open(filepath, "w", encoding=encoding) as f:
#     264         f.write(code)
#
# ...

# %%
def explore_matrix(matrix):
    print(matrix.shape)

    flat = np.matrix.flatten(matrix)
    delta_star = flat[flat > 0].min()
    delta_star_star = 0

    for i, row in enumerate(matrix):
        delta_star_star = max(delta_star_star, row[row > 0].min())

    print(delta_star, delta_star_star, delta_star_star/delta_star)
    
explore_matrix(dist_matrix_2)
explore_matrix(dist_matrix_3)
# Out:
# (4374, 4374)
# 7.755314099244792e-10 0.0018276718994475194 2356670.376027061
# (4374, 4374)
# 6.184291880306011e-10 0.4276114879613395 691447778.076381

# %%
import scipy

print('matplotlib: {}'.format(scipy.__version__))
# Out:
# matplotlib: 1.10.1
